# %%
from ultralytics import YOLO

# %%
model_path = r"C:\Users\SaiRamPenjarla\Desktop\Project\YOLOV10\runs\mlflow\237155232739678261\b1c5387822dc45f69a8a4018b356ba40\artifacts\weights\best.pt"
image_path = r"C:\Users\SaiRamPenjarla\Desktop\Project\YOLOV10\archive\images\14.png"

# %%
import cv2
from PIL import Image
from ultralytics import YOLOv10

model = YOLOv10(model_path)
# accepts all formats - image/dir/Path/URL/video/PIL/ndarray. 0 for webcam
results = model.predict(source="0")
results = model.predict(source="folder", show=True)  # Display preds. Accepts all YOLO predict arguments

# from PIL
im1 = Image.open(image_path)
results = model.predict(source=im1, save=True)  # save plotted images

# from ndarray
im2 = cv2.imread("bus.jpg")
results = model.predict(source=im2, save=True, save_txt=True)  # save predictions as labels

# from list of PIL/ndarray
results = model.predict(source=[im1, im2])
# Out:
# 1/1: 0... Success ✅ (inf frames of shape 640x480 at 30.00 FPS)
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 5 free_parking_spaces, 3 not_free_parking_spaces, 388.2ms
# 0: 480x640 6 free_parking_spaces, 3 not_free_parking_spaces, 370.8ms
# 0: 480x640 5 free_parking_spaces, 1 not_free_parking_space, 418.0ms
# 0: 480x640 6 free_parking_spaces, 1 not_free_parking_space, 451.6ms
# 0: 480x640 6 free_parking_spaces, 2 not_free_parking_spaces, 473.3ms
# ...
